# %%
from sklearn.preprocessing import normalize
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
import matplotlib.pyplot as plt
import librosa

# %%
path = "/Users/junhyuckwoo/capstone/TestFile/ProceedData/phantom2_44100_1s/100.wav"

# %%
test, sr = librosa.load(path, sr=44100)

# %%
plt.plot(test)
plt.ylabel("Sample Values")
plt.xlabel("time (1 sec)")
# Out:
# Text(0.5, 0, 'time (1 sec)')

# %%
normalize_test = maxabs_scale(test)

# %%
plt.plot(normalize_test)
plt.ylabel("Sample Values")
plt.xlabel("time (1 sec)")
# Out:
# Text(0.5, 0, 'time (1 sec)')

# %%
print("test: ", test.shape)
# Out:
# test:  (44100,)

# %%
print("normalize: ", normalize_test.shape)
# Out:
# normalize:  (44100,)

# %%
from sklearn.preprocessing import normalize
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %%
path = "/Users/junhyuckwoo/capstone/TestFile/ProceedData/phantom2_44100_1s/100.wav"

# %%
test, sr = librosa.load(path, sr=44100)

# %%
scaled_test = maxabs_scale(test)
plt.plot(scaled_test)
plt.ylabel("Sample Values")
plt.xlabel("time (1 sec)")
print("Test: ", test.shape)
print("Scaled_test: ", scaled_test.shape)
# Out:
# Test:  (44100,)
# Scaled_test:  (44100,)

# %%
hl = 86
fl = hl+1

# %%
zc_test = librosa.feature.zero_crossing_rate(test, frame_length=fl,  hop_length=hl)
plt.plot(zc_test[0])
